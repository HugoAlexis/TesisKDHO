# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.style as stl
import matplotlib.ticker as ticker
import matplotlib.colors
stl.use('seaborn')
import pandas as pd

from DampedKHO import *

# %%
from matplotlib import animation, rc
from IPython.display import HTML

# %% [markdown]
# ## Algunas pruebas

# %%
t_system = DampedKHO(5000, kappa=0, kbt_ext=15, omega=1.5, q=4)
t_system.make_n_kicks(50)

# %%
t_system.kappa = -2.5
t_system.make_n_kicks(30)

# %%
t_system.kappa = 0
t_system.coef = 0
for kick in range(35):
    t_system.omega -= 0.01
    t_system.make_kick()

# %% [markdown]
# ## **Ciclo termodinamico sin patadas**

# %%
t_system = DampedKHO(5000, kappa=0, kbt_ext=5, omega=1.5, q=4)

t_system.make_n_kicks(60)

omegas1, energies1 = [], []
while t_system._kbt_ext < 10:
    t_system._kbt_ext += 0.1
    t_system.make_n_kicks(2)
    omegas1.append(t_system.omega)
    energies1.append(t_system.last_mean_energy())

# %%
omegas2, energies2 = [], []
t_system.coef = 0
while t_system.actual_energy() > 5:
    t_system.omega -= 0.01
    t_system.make_n_kicks(1)
    omegas2.append(t_system.omega)
    energies2.append(t_system.last_mean_energy())

# %%
omegas3, energies3 = [], []
t_system.coef = 0.1
t_system._kbt_ext = 5
while t_system.omega < 1.5:
    t_system.omega += 0.005
    t_system.make_n_kicks(1)
    omegas3.append(t_system.omega)
    energies3.append(t_system.last_mean_energy())

# %%
fig, ax = plt.subplots(figsize=(11, 7))

ax.plot(omegas1, energies1, color='red', marker='o', 
        linestyle='', label='Proceso isocorico')
ax.plot(omegas2, energies2, color='black', marker='o', 
        linestyle='', label='Proceso adiabatico')
ax.plot(omegas3, energies3, color='blue', marker='o', 
        linestyle='', label='Proceso isotermico')
ax.legend()
ax.axis([0, 2, 0, 12])
#ax.axis([0.7, 1.6,4, 10])
plt.show()

# %% [markdown]
# ## **Ciclo termodinamico con patadas**

# %%
t_system = t_system = DampedKHO(5000, kappa=0, kbt_ext=5, omega=1.5, q=4)

t_system.make_n_kicks(60)

t_system.kappa = -2.5
omegas1, energies1 = [], []
while len(omegas1) < 70:
    t_system.make_n_kicks(1)
    omegas1.append(t_system.omega)
    energies1.append(t_system.last_mean_energy())

# %%
omegas2, energies2 = [], []
t_system.coef = 0
t_system.kappa = 0
while t_system.actual_energy() > 5:
    t_system.omega -= 0.01
    t_system.make_n_kicks(1)
    omegas2.append(t_system.omega)
    energies2.append(t_system.last_mean_energy())

# %%
t_system.omega
omegas3, energies3 = [], []

# %%
omegas3, energies3 = [], []
t_system.coef = 0.1

while t_system.omega < 1.5:
    t_system.omega += 0.005
    t_system.make_n_kicks(1)
    omegas3.append(t_system.omega)
    energies3.append(t_system.last_mean_energy())

# %%
fig, ax = plt.subplots(figsize=(16, 11))

ax.plot(omegas1, energies1, color='red', marker='o', 
        linestyle='', label='Proceso con patadas, $\kappa = -2.5$')
ax.plot(omegas2, energies2, color='black', marker='o', markersize=3,
        linestyle='', label='Proceso adiabatico')
ax.plot(omegas3, energies3, color='blue', marker='o', 
        linestyle='', label='Proceso isotermico')
ax.legend()
ax.axis([0, 2, 0, 30])
#ax.axis([0.7, 1.6,4, 10])
plt.show()

# %% [markdown]
# ## **Ciclo termodinamico 2 con patadas**

# %%
t_system = t_system = DampedKHO(5000, kappa=-1.5, kbt_ext=5, omega=1.5, q=4)

t_system.make_n_kicks(60)

t_system.kappa = -2.5
omegas1b, energies1b = [], []
for i in range(70):
    t_system.make_n_kicks(1)
    omegas1b.append(t_system.omega)
    energies1b.append(t_system.last_mean_energy())

# %%
omegas2b, energies2b = [], []

while t_system.omega > 0.27:
    t_system.omega -= 0.005
    t_system.make_n_kicks(1)
    omegas2b.append(t_system.omega)
    energies2b.append(t_system.last_mean_energy())

# %%
t_system.kappa = -1.5
omegas3b, energies3b = [], []
while len(omegas3b) < 70:
    t_system.make_n_kicks(1)
    omegas3b.append(t_system.omega)
    energies3b.append(t_system.last_mean_energy())

# %%
omegas4b, energies4b = [], []

t_system.coef = 0.1
while t_system.omega < 1.5:
    t_system.omega += 0.005
    t_system.make_n_kicks(1)
    omegas4b.append(t_system.omega)
    energies4b.append(t_system.last_mean_energy())

# %%
fig, ax = plt.subplots(figsize=(11, 7))

ax.plot(omegas1b, energies1b, marker='o', markersize=5, 
        color='red')
ax.plot(omegas2b, energies2b, marker='o', markersize=5, 
        color='blue')
ax.plot(omegas3b, energies3b, marker='o', markersize=5, 
        color='red')
ax.plot(omegas4b, energies4b, marker='o', markersize=5,
        color='black')

ax.axis([0, 1.75, 0, 30])
# Out:
# (0.0, 1.75, 0.0, 30.0)

# %%
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ["black","yellow","red", "RED"])

# %%
t_system = t_system = DampedKHO(5000, kappa=0, kbt_ext=5, omega=1.5, q=4)

t_system.make_n_kicks(60)

t_system.kappa = -2.5
omegas1, energies1 = [], []
while len(omegas1) < 70:
    t_system.make_n_kicks(1)
    omegas1.append(t_system.omega)
    energies1.append(t_system.last_mean_energy())

# %%
fig, axs = plt.subplots(10, 10, figsize=(90, 90))
axs = axs.flat

omegas2, energies2 = [], []
t_system.coef = 0
t_system.kappa = 0
t_system.q = 32
i = 0
while t_system.actual_energy() > 5:
    t_system.omega -= 0.001
    t_system.make_n_kicks(1)
    if i < 30:
        axs[i].hist2d(t_system._xp_state[:, 0], t_system._xp_state[:, 1], cmap=cmap, bins=120)
    i += 1
    omegas2.append(t_system.omega)
    energies2.append(t_system.last_mean_energy())

# %%
omegas3, energies3 = [], []
t_system.coef = 0.1
t_system.q = 4
while t_system.omega < 1.5:
    t_system.omega += 0.005
    t_system.make_n_kicks(1)
    omegas3.append(t_system.omega)
    energies3.append(t_system.last_mean_energy())

# %%
fig, ax = plt.subplots(figsize=(16, 11))

ax.plot(omegas1, energies1, color='red', marker='o', 
        linestyle='', label='Proceso isocorico')
ax.plot(omegas2, energies2, color='black', marker='o', markersize=3,
        linestyle='', label='Proceso adiabatico')
#ax.plot(omegas3, energies3, color='blue', marker='o', 
#        linestyle='', label='Proceso isotermico')
ax.legend()
ax.axis([0, 2, 0, 30])
#ax.axis([0.7, 1.6,4, 10])
plt.show()
